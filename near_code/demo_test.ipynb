# %%
import numpy as np

# %%
train_ex = np.load('data/example/train_ex_data.npy')
train_ex_labels = np.load('data/example/train_ex_labels.npy')
print(len(train_ex))
print(train_ex.shape)
print(train_ex[0])
print(len(train_ex_labels))
print(train_ex_labels.shape)
print(train_ex_labels[0])
# Out:
# 250
# (250, 20, 12)
# [[0.35353777 0.46556404 0.9316767  0.08121594 0.02559193 0.5659378
#   0.86104757 0.16191578 0.6626359  0.2512865  0.3043242  0.7063684 ]
#  [0.4118712  0.2719815  0.26243955 0.9343837  0.80671656 0.31857017
#   0.6883084  0.4655571  0.6035853  0.7879667  0.2620404  0.39451438]
#  [0.7618056  0.32711205 0.20314808 0.42853883 0.972454   0.88263553
#   0.40468046 0.9978582  0.6796004  0.47644338 0.16701683 0.01363619]
#  [0.48665664 0.49526414 0.1459766  0.4111498  0.57366234 0.43819535
#   0.07982959 0.8340454  0.25863254 0.7961835  0.76737803 0.5792274 ]
#  [0.06204455 0.42462388 0.20725815 0.46911296 0.29590684 0.12729074
#   0.7673758  0.8478809  0.9074065  0.53661925 0.09364713 0.4077694 ]
#  [0.9939644  0.80137914 0.14162605 0.07929119 0.7713539  0.1835891
#   0.7317954  0.3437757  0.11947748 0.6396891  0.7551779  0.5939424 ]
#  [0.5486793  0.52192956 0.29720184 0.65809697 0.4347893  0.7983383
# ...

# %%
train_ecg = np.load('data/ecg_test/x_train.npy')
train_ecg_labels = np.load('data/ecg_test/y_train.npy')

print(train_ecg.shape)
print(train_ecg_labels.shape)
# Out:
# (4813, 144)
# (4813, 9)
